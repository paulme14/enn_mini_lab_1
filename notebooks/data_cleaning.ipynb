# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# Anforderungen:
#     Feature auswählen
#     Perform complete cleaning pipeline: <br>
#     - Remove invalid rows (e.g., livingSpace <= 10) <br>
#     - Fill missing values (median for numeric, mode for categorical) <br>
#     - Encode categorical features <br>
#     - Keep only numeric columns <br>

# %%
df = pd.read_csv("../data/train.csv")
df
# Out:
#                   regio1  serviceCharge                     heatingType  \
# 0    Nordrhein_Westfalen         235.00                 central_heating
# 1    Nordrhein_Westfalen         180.00                       heat_pump
# 2    Nordrhein_Westfalen         140.00                     gas_heating
# 3    Nordrhein_Westfalen         180.00  self_contained_central_heating
# 4    Nordrhein_Westfalen         170.00                             NaN
# ..                   ...            ...                             ...
# 341  Nordrhein_Westfalen         160.00                   floor_heating
# 342  Nordrhein_Westfalen         440.00                district_heating
# 343  Nordrhein_Westfalen         315.00                 central_heating
# 344  Nordrhein_Westfalen         513.04                district_heating
# 345  Nordrhein_Westfalen         180.00                 central_heating
#
#     telekomTvOffer  telekomHybridUploadSpeed  newlyConst  balcony  \
# ...

# %% [markdown]
# # Featureauswahl

# %%
df.columns
# Out:
# Index(['regio1', 'serviceCharge', 'heatingType', 'telekomTvOffer',
#        'telekomHybridUploadSpeed', 'newlyConst', 'balcony', 'picturecount',
#        'pricetrend', 'telekomUploadSpeed', 'totalRent', 'yearConstructed',
#        'scoutId', 'noParkSpaces', 'firingTypes', 'hasKitchen', 'geo_bln',
#        'cellar', 'yearConstructedRange', 'baseRent', 'houseNumber',
#        'livingSpace', 'geo_krs', 'condition', 'interiorQual', 'petsAllowed',
#        'street', 'streetPlain', 'lift', 'baseRentRange', 'typeOfFlat',
#        'geo_plz', 'noRooms', 'thermalChar', 'floor', 'numberOfFloors',
#        'noRoomsRange', 'garden', 'livingSpaceRange', 'regio2', 'regio3',
#        'description', 'facilities', 'heatingCosts', 'energyEfficiencyClass',
#        'lastRefurbish', 'electricityBasePrice', 'electricityKwhPrice', 'date',
#        'americanArea'],
#       dtype='object')

# %% [markdown]
# | Column | isFeature | Reason
# | ---- | ----| --|
# | regio1 | NO | 'Nordrhein_Westfalen' ist der einzige Wert|
# | serviceCharge | NO  | wird durch Markler bestimmt, möglicherweße nachdem die Miete festgelegt wurde, also kein Zusammenhang   |
# | heatingType | YES | hat Einfluss auf Nebenkosten |
# | telekomTvOffer | NO |  wenn überhaupt minimaler Eifluss, schlechte Datenqualität |
# | telekomHybridUploadSpeed | NO | schlechte Datenqualität |
# | newlyConst | YES | kürzlich renoviert?  |
# | balcony | YES  |   |
# | picturecount | NO |  |
# | pricetrend | ?? | sagt was aus?|
# | telekomUploadSpeed | ?? | keine Meinung |
# | totalRent | NO | macht kein Sinn |
# | yearConstructed | MAYBE | hat viele null Values |
# | scoutId | NO | irrelevant |
# | noParkSpaces | ?? | schlechte Datengrundlage, ein Eintag mit 27?? |
# | firingTypes | YES |  |
# | hasKitchen | YES |  |
# | geo_bln | NO  | nur Nordrhein_Westfalen als Wert|
# | cellar | YES |  |
# | yearConstructedRange | ?? | sagt was aus? |
# | baseRent | NO  | Target value |
# | houseNumber | NO |  |
# | livingSpace | YES | qm Wohnung |
# | geo_krs | NO   | nur Münster als Wert |
# | condition | YES | mapping auf num werte genauer anschauen |
# | interiorQual | YES |  |
# | petsAllowed | YES | schlechte Datenqualität |
# | street | NO |  |
# | streetPlain | NO |  |
# | lift | YES |  |
# | baseRentRange | ?? | sagt was aus? |
# | typeOfFlat | MAYBE | schwer zu quantifizieren |
# | geo_plz | NO |  |
# | noRooms | MAYBE | zusammen mit livingSpace over emphasize on space |
# | thermalChar | ?? | sagt was aus? |
# | floor | MAYBE | kann einfluss auf Preis haben |
# | numberOfFloors | ?? | sagt was aus? |
# | noRoomsRange | ?? | sagt was aus? |
# | garden | YES |  |
# | livingSpaceRange | ?? | sagt was aus? |
# | regio2 | NO | nur Münster |
# | regio3 | NO | Stadtteil schwer zu quantifizieren |
# | description | NO | nicht analysierbar  |
# | facilities | NO | nicht analysierbar |
# | heatingCosts | YES |  |
# | energyEfficiencyClass | YES |  |
# | lastRefurbish | MAYBE | schlechte Datenlage |
# | electricityBasePrice | NO | schlechte Datenlage |
# | electricityKwhPrice | NO | schlechte Datenlage |
# | date | NO |  |
# | americanArea | NO |  |

# %%
df['newlyConst'].value_counts(dropna=False)
# Out:
# newlyConst
# False    279
# True      65
# Name: count, dtype: int64

# %% [markdown]
# Remove invalid rows (e.g., livingSpace <= 10)

# %%
df = df[df['livingSpace'] > 10]
